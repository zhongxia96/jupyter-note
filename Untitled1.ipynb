# %%
import os

# %%
import tensorflow

# %%
import tensorflow as tf

# %%
os.environ["CUDA_VISIBLE_DEVICES"] =  "7"

# %%
# %run /home/jinhanqi/tf_program/summarization_baseline/gigaword_seq2seq/test_summarization.py
# Out:
# INFO:tensorflow:Starting seq2seq_attention in decode mode...
# max_size of vocab was specified as 124406; we now have 124406 words. Stopping reading.
# Finished constructing vocabulary of 124406 total words. Last word added: great-great-grandson
# hps.hidden_dim: 500
# build graph...
# INFO:tensorflow:build graph...
# count of articles: 1952
# count of abstracts: 1952
# loading checkpoint from  /home/jinhanqi/tf_program/summarization_log/gigaword_seq2seq/train/model.ckpt-832975
# INFO:tensorflow:Restoring parameters from /home/jinhanqi/tf_program/summarization_log/gigaword_seq2seq/train/model.ckpt-832975
#
# ARTICLE:  japan 's nec corp. and __UNK__ computer corp. of the united states said wednesday they had agreed to join forces in supercomputer sales .
# REFERENCE SUMMARY:  nec __UNK__ in computer sales tie-up
# GENERATED SUMMARY:  nec UNK to join forces in supercomputer
#
#
# ...

# %%
# !nvidia-smi
# Out:
# Fri Jul 20 23:27:02 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.25                 Driver Version: 390.25                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  On   | 00000000:04:00.0 Off |                  N/A |
# | 50%   64C    P2   169W / 250W |   8873MiB / 11178MiB |     73%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  On   | 00000000:05:00.0 Off |                  N/A |
# | 29%   26C    P8    14W / 250W |      1MiB / 11178MiB |      0%      Default |
# ...

# %%
# !nvidia-smi
# Out:
# Fri Jul 20 23:25:42 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.25                 Driver Version: 390.25                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  On   | 00000000:04:00.0 Off |                  N/A |
# | 51%   66C    P2   205W / 250W |  11176MiB / 11178MiB |     80%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  On   | 00000000:05:00.0 Off |                  N/A |
# | 29%   26C    P8    14W / 250W |      1MiB / 11178MiB |      0%      Default |
# ...

# %%
# !pip install pandas --user
# Out:
# ...
#     100% |████████████████████████████████| 8.9MB 27kB/s ta 0:00:011
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !pip install numpy --user
# Out:
# ...
# You are using pip version 9.0.1, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# !nvidia-smi
# Out:
# Sat Jul 21 08:48:04 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 390.25                 Driver Version: 390.25                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  On   | 00000000:04:00.0 Off |                  N/A |
# | 49%   65C    P2   148W / 250W |   8575MiB / 11178MiB |     74%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  On   | 00000000:05:00.0 Off |                  N/A |
# | 29%   27C    P8    14W / 250W |      1MiB / 11178MiB |      0%      Default |
# ...
