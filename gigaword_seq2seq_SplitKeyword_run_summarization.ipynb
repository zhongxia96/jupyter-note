# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] =  "0"

# %%
# %run /home/jinhanqi/tf_program/summarization_baseline/gigaword_seq2seq_SplitKeyword/run_summarization.py --lr=0.1 --max_dec_steps=20 --exp_name=gigaword_seq2seq_SplitKeyword_maxdecsteps20
# Out:
# INFO:tensorflow:Starting seq2seq_attention in train mode...
# max_size of vocab was specified as 124406; we now have 124406 words. Stopping reading.
# Finished constructing vocabulary of 124406 total words. Last word added: great-great-grandson
# hps.hidden_dim: 500
# creating model...
# finish create  model...
# build graph....
# INFO:tensorflow:build graph...
# count of articles: 3803958
# count of abstracts: 3803958
# WARNING:tensorflow:From /home/jinhanqi/tf_program/summarization_baseline/gigaword_seq2seq_SplitKeyword/run_summarization.py:108: __init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Starting standard services.
# INFO:tensorflow:Starting queue runners.
# INFO:tensorflow:global_step/sec: 0
# ...
